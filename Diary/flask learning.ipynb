# %% [markdown]
# ## 15-11 Draw Steel noticeboard

# %% [markdown]
# Note to self, python can have strong type checking using : after a variable is declared
#
# maybe adopt this practice for making code readability clearer

# %%
key: str = "hey"
print(key)
# Out:
# 0
